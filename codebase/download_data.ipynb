# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.6)

# %% [markdown]
# # Download Kaggle dataset

# %%
# !git clone https://github.com/SIH-22-Kyogre/EyeSea_Image-Preprocessing-Algorithms.git
# Out:
# Cloning into 'EyeSea_Image-Preprocessing-Algorithms'...
# remote: Enumerating objects: 960, done.
# remote: Counting objects: 100% (960/960), done.
# remote: Compressing objects: 100% (568/568), done.
# remote: Total 960 (delta 535), reused 776 (delta 375), pack-reused 0 (from 0)
# Receiving objects: 100% (960/960), 9.51 MiB | 9.51 MiB/s, done.
# Resolving deltas: 100% (535/535), done.

# %%
import os
import json
import pathlib
import httpx
from tqdm.notebook import tqdm
from threading import Thread
from queue import Queue

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_json = pathlib.Path('/content/drive/MyDrive/fathomnet-out-of-sample-detection/object_detection/train.json')
eval_json = pathlib.Path('/content/drive/MyDrive/fathomnet-out-of-sample-detection/object_detection/eval.json')

# %%
with train_json.open() as f:
    train_data = json.load(f)

with eval_json.open() as f:
    eval_data = json.load(f)

# %%
from threading import Thread
from queue import Queue


def download_image(url, path):
    while True:
        try:
            r = httpx.get(url)
            break
        except:
            pass

    with open(path, 'wb') as f:
        f.write(r.content)


def download_images(images, path):
    pathlib.Path(path).mkdir(parents=True, exist_ok=True)
    q = Queue()
    for image in images:
        q.put(image)


    def worker():
        while not q.empty():
            image = q.get()
            download_image(image['coco_url'], os.path.join(path, image['file_name']))
            q.task_done()

    for _ in range(32):
        t = Thread(target=worker)
        t.daemon = True
        t.start()
    q.join()

# %%
download_images(train_data['images'], '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train')

# %% [markdown]
# # Convert RGBA to RGB

# %% [markdown]
# The processing algorithm only works wirh RGB image, so we have to convert RGBA to RGB

# %%
from PIL import Image
import os

def convert_rgba_to_rgb(data_path):
    for root, _, files in os.walk(data_path):
        for file in files:
            if file.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                file_path = os.path.join(root, file)
                try:
                    with Image.open(file_path) as img:
                        if img.mode == 'RGBA':
                            print(f"Converting {file} from RGBA to RGB...")
                            rgb_img = img.convert('RGB')
                            rgb_img.save(file_path)
                except Exception as e:
                    print(f"Error processing {file}: {e}")

convert_rgba_to_rgb('/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/')
# Out:
# Converting 286d6058-1cef-4ea2-8c74-48fbb4e92da9.png from RGBA to RGB...
# Converting 30be6c64-1f81-44ea-ad16-6ed5e35098a3.png from RGBA to RGB...
# Converting fe44ec61-2552-4cca-9699-b0cbe4980d3d.png from RGBA to RGB...
# Converting 1abec2b7-88c7-4fb1-a0f8-3ce68d0d6ec5.png from RGBA to RGB...
# Converting ae1f1804-5cbd-45b8-b612-c90f2b2f59ee.png from RGBA to RGB...
# Converting 024cba58-2d78-4026-bd01-0b04069c65a5.png from RGBA to RGB...
# Converting 7a6d1aa3-96d9-442e-8bb8-354b3975b9d2.png from RGBA to RGB...
# Converting 0f8a9ac8-79ee-4b98-9662-149dfaa977d0.png from RGBA to RGB...
# Converting 0fa6d0b4-78e2-42b2-b832-52d6edf77d6a.png from RGBA to RGB...
# Converting 149210bd-2127-4de3-a2ad-698df8c9179f.png from RGBA to RGB...
# Converting ca0269ae-070e-4be4-8022-034a25b69395.png from RGBA to RGB...
# Converting b47f3d66-2e98-4a53-9ebd-a9e1c8a4c2b3.png from RGBA to RGB...
# Converting c53d6ca9-9427-44c2-94b3-1049142d9113.png from RGBA to RGB...
# Converting 63aba599-b29a-4be5-9a0e-7f189be1f1c5.png from RGBA to RGB...
# Converting 0cacb924-f5ec-4818-8ffd-0d030253349f.png from RGBA to RGB...
# Converting 235e49f9-c0b1-4726-8bd6-9182ddb4b85f.png from RGBA to RGB...
# Converting 2a731088-7f0b-4cc6-ba19-ccfc6b7a4724.png from RGBA to RGB...
# Converting b41516b8-e2aa-4c85-9608-bd13a020d8e7.png from RGBA to RGB...
# Converting 4c1e69c4-3165-46fd-9d01-e27e316550f5.png from RGBA to RGB...
# Converting c8056249-953a-4af5-9209-fcf94ca0751b.png from RGBA to RGB...
# Converting fe0ed8c7-558b-43ae-a3d2-57d8ec9a7d0e.png from RGBA to RGB...
# Converting d732eb4f-e448-4046-b0b9-a64f334fe833.png from RGBA to RGB...
# Converting 2905dec2-3fca-4d4f-b317-49ba7e4ec884.png from RGBA to RGB...
# Converting 9c849e3d-9d39-4190-8617-705eff91f3f2.png from RGBA to RGB...
# Converting e44ff955-e089-4e3b-99e3-73410a1a8b79.png from RGBA to RGB...
# Converting 85906e19-06a3-49df-85db-a79ed42039c1.png from RGBA to RGB...
# Converting 11a342ab-8825-4b3a-beae-da357adb66e1.png from RGBA to RGB...
# Converting acd854b2-a302-48b7-8b4a-565716e01c39.png from RGBA to RGB...
# Converting 474913ba-e365-4484-8fc7-6ba94a34f522.png from RGBA to RGB...
# Converting fe02fe8e-652e-4aec-bc27-a04d94bb8b65.png from RGBA to RGB...
# Converting dc6ddec8-add5-4bed-9484-5b7216611a37.png from RGBA to RGB...
# Converting 56fd5708-5af3-4391-bb0e-27a87be99e62.png from RGBA to RGB...
# Converting 1eca4a0c-115c-4cad-a229-395cfcd8b91a.png from RGBA to RGB...
# Converting e4ca04f0-9f88-4935-bb33-707462248d4a.png from RGBA to RGB...
# Converting 5cb86ab1-4c6f-452e-8b33-b8618253af65.png from RGBA to RGB...
# Converting dfb3ea61-899a-4b42-a921-14df1804fdc4.png from RGBA to RGB...
# Converting 656c072c-d3b9-4d5a-95a1-8970f8707c45.png from RGBA to RGB...
# Converting 2b473924-c843-4704-af1e-b2fff7438880.png from RGBA to RGB...
# Converting f5ff6c95-a0b6-4037-b7d4-6c12963145ac.png from RGBA to RGB...
# Converting 27991963-29a0-46a1-b9a6-ca7a845bd37d.png from RGBA to RGB...
# Converting 799aab81-d589-4fca-a358-b065f663d47d.png from RGBA to RGB...
# Converting e4db1905-a571-4335-8689-d4c97b7c575e.png from RGBA to RGB...
# Converting bef15dbd-6b3e-4886-88a0-a151b1705fef.png from RGBA to RGB...
# Converting 4475c422-8b44-4d05-973c-cef7ece38709.png from RGBA to RGB...
# Converting 152edc6b-99ac-40f6-a83e-c45cfd4186f8.png from RGBA to RGB...
# Converting 09daa0bc-f919-44dc-923e-d3f6ff0fd276.png from RGBA to RGB...
# Converting bad39939-7844-4939-81e9-4a00f627a3b9.png from RGBA to RGB...
# Converting 3ade5857-3029-4f4e-8e6a-8c5ee583f338.png from RGBA to RGB...
# Converting 26ee4a81-8ac5-4c85-ae25-dd14bab2ab60.png from RGBA to RGB...
# Converting 6f807024-06fd-4a1e-a6dd-01f047268834.png from RGBA to RGB...
# Converting 68249856-171e-4cf5-9f61-6ea4e7f5d492.png from RGBA to RGB...
# Converting b449200e-ae72-437d-af3b-2a6136c71f87.png from RGBA to RGB...
# Converting 0bbd0bdb-75ba-4709-b9bd-ad69239516d1.png from RGBA to RGB...
# Converting fc3b6ae0-e68c-489f-87cd-e76ab13d8386.png from RGBA to RGB...
# Converting 0bfd08d4-36e9-4333-9a38-012a505b7647.png from RGBA to RGB...
# Converting 00727ef4-3467-419c-9f7d-cb536a18d21d.png from RGBA to RGB...
# Converting 2ec66e02-a37e-4f18-a8af-ccb93ae94f7e.png from RGBA to RGB...
# Converting f89e83bf-f74c-4f54-a711-1fbb9a90b72e.png from RGBA to RGB...
# Converting 8f077240-16b1-4be6-87b2-01b14ebc8766.png from RGBA to RGB...
# Converting 0d8dc43b-34ec-47b9-8f25-b6114817a649.png from RGBA to RGB...
# Converting e7c33ee5-cbeb-4ddd-bfab-dc0888f49e82.png from RGBA to RGB...
# Converting 602b9fda-a10b-432a-b12d-4b2766080a37.png from RGBA to RGB...
# Converting 2e396e05-3583-41ae-b6ec-37cb7120a8b9.png from RGBA to RGB...
# Converting ffd1cb7d-fa64-404c-85a9-2f638e51d542.png from RGBA to RGB...
# Converting 4dcd0fdf-4666-49ed-821c-7dc65cf90135.png from RGBA to RGB...
# Converting edcd275e-f8e5-4a34-a4eb-0bc2c7c58110.png from RGBA to RGB...
# Converting 19b8931c-cf33-4d88-a72d-766ddcffdec1.png from RGBA to RGB...
# Converting 8c4facb5-7df9-4569-befa-e5a08d04ab4e.png from RGBA to RGB...
# Converting d9e02c6e-6b3c-48ec-b609-a20cd2dcf0d9.png from RGBA to RGB...
# Converting 11d6b193-ac92-41fa-85f1-797e46c5e730.png from RGBA to RGB...
# Converting 856978b0-d2a1-485b-904a-acae1b53eb9f.png from RGBA to RGB...
# Converting 31ae7ddb-ee6b-4ca2-a4c0-76a4c82b13ea.png from RGBA to RGB...
# Converting 7933291f-6f5e-4709-800b-6184fd5e80af.png from RGBA to RGB...
# Converting fed91ec7-55c6-493d-946d-e0418bcf8b26.png from RGBA to RGB...
# Converting 83c18721-d874-426e-9991-0aa11be18069.png from RGBA to RGB...
# Converting 70311a9b-8ef4-48d1-958c-e6ed439a4ddc.png from RGBA to RGB...
# Converting a7795de1-8be2-4a09-8e6a-8ceee8d6682f.png from RGBA to RGB...
# Converting ff708219-30fc-4a2a-8eb3-dbe8c9930f63.png from RGBA to RGB...
# Converting 2b26b7f4-a88e-4096-a7be-aa4db48639b7.png from RGBA to RGB...
# Converting ad75751c-0aca-46f9-b67c-df9f93ed75df.png from RGBA to RGB...
# Converting bd852d40-b8d4-4ea5-80b6-e52de962df7d.png from RGBA to RGB...
# Converting eb0ab4a1-236f-433f-bfeb-50722e57da96.png from RGBA to RGB...
# Converting c336ff8d-c756-4f17-8dc0-dd9882a82c9f.png from RGBA to RGB...
# Converting 3ae3fa5d-dd1e-4a5b-a42b-9db446db41ab.png from RGBA to RGB...
# Converting f2e5278b-bb30-4ac2-80b9-15b5c49b6c43.png from RGBA to RGB...
# Converting 92491d06-e5fd-4f08-817c-0f72f31f14cd.png from RGBA to RGB...
# Converting f695ab36-b6ec-4922-9d11-95636072dcba.png from RGBA to RGB...
# Converting 28e4012c-c149-4f3f-be6e-cfeae908aa7f.png from RGBA to RGB...
# Converting fd45b8b2-8217-4adf-ad78-b08fc43f579e.png from RGBA to RGB...
# Converting 6ecd782c-1b87-41fa-be19-bcfc15ed9e8a.png from RGBA to RGB...
# Converting e441ea05-1843-40f7-b9cb-009e628155b7.png from RGBA to RGB...
# Converting 482a91f8-4d9e-47f6-8ffd-5e3b7d7a0f69.png from RGBA to RGB...
# Converting d7991036-cbfc-418e-aa9a-ffb3145e85f6.png from RGBA to RGB...
# Converting 9c8ea60b-dcbf-45d0-9ed6-4a3a2289eb7c.png from RGBA to RGB...
# Converting c3b65bb5-4411-437f-9b51-e76dd3b3f0d5.png from RGBA to RGB...
# Converting ec018d2a-20dd-4cb5-8cef-4eda970ab74d.png from RGBA to RGB...
# Converting bde54b2f-ad7e-4114-9279-857937535971.png from RGBA to RGB...
# Converting c2b1f14e-bce2-4208-9739-b42230905677.png from RGBA to RGB...
# Converting d38f6e9e-8fe1-437a-8843-952e635b52e5.png from RGBA to RGB...
# Converting 97f7a60f-35e1-43b1-83b3-7c2a388a202f.png from RGBA to RGB...
# Converting 7130e42e-6407-41f6-8a67-a9e7f0d8ae19.png from RGBA to RGB...
# Converting cf6e32e2-b307-492b-9bfa-32eac70681d1.png from RGBA to RGB...
# Converting a180c64d-7542-46c2-9068-e781c18a3a63.png from RGBA to RGB...
# Converting 25f1a4d0-bf53-4a77-8f72-cfad3c5e43ec.png from RGBA to RGB...
# Converting 13d043ec-7feb-49aa-9abb-e4a6c74faeaa.png from RGBA to RGB...
# Converting 0bb2f69b-07e7-44fb-b0a8-2fe2dd210852.png from RGBA to RGB...
# Converting 811505c2-76ef-4be0-9dc3-cf9e133a7219.png from RGBA to RGB...
# Converting 825d37d0-e794-4f7e-8746-1b38948685b8.png from RGBA to RGB...
# Converting 527bdbc7-7c24-4579-bbf1-2a2317250a7d.png from RGBA to RGB...
# Converting e852b16a-001b-4ff7-91a5-05cd3227bcc6.png from RGBA to RGB...
# Converting 62085d61-171b-4557-a9fc-aec95d51e1f2.png from RGBA to RGB...
# Converting 7496fe96-ef6c-461c-808b-00127bbc927f.png from RGBA to RGB...
# Converting b81d0b61-fbb4-448b-aa09-44a697554c36.png from RGBA to RGB...
# Converting 7532cf65-3f1f-4bad-b5ef-6090c3cea33c.png from RGBA to RGB...
# Converting 1dd5c7c9-159b-47ae-ac78-d1f3802267a1.png from RGBA to RGB...
# Converting 6b9460c0-6eb1-4e2b-a76b-c8dc6e6c7dde.png from RGBA to RGB...
# Converting 0dd12fff-b1b4-4e49-83a8-8eb9c5a4d7ba.png from RGBA to RGB...
# Converting e9dcddac-6ac6-49da-b576-08b819a677f8.png from RGBA to RGB...
# Converting 3be2cf36-a4ae-45f7-a794-528171bc1123.png from RGBA to RGB...
# Converting 662facfa-36fa-459f-a5c6-435b561d57e7.png from RGBA to RGB...
# Converting 06b46506-f61b-4951-91fc-016290534ed9.png from RGBA to RGB...
# Converting e1373e80-62f3-4ba2-b3dd-557ab86f1804.png from RGBA to RGB...
# Converting 54200714-78b6-4ba8-b367-1af6624882d2.png from RGBA to RGB...
# Converting 768d2f55-6297-43cf-9c6b-6e1f72fbdf86.png from RGBA to RGB...
# Converting 54df2ab4-4d3c-4bc2-93d1-e301b04731c6.png from RGBA to RGB...
# Converting d154e4e6-a487-442d-ba64-66da352ae68c.png from RGBA to RGB...
# Converting 626e7676-fb90-4bdc-9cb2-9bf931e8b91d.png from RGBA to RGB...
# Converting b584a3f4-f345-4b3d-8d91-566f25a551c8.png from RGBA to RGB...
# Converting f3aadea1-2c03-4109-a97c-eca931474fa6.png from RGBA to RGB...
# Converting 17f0e092-69f1-42aa-9a66-a1381fdbf026.png from RGBA to RGB...
# Converting 36edc0ec-0902-4ff4-a170-f70187d8ff39.png from RGBA to RGB...
# Converting 30ffd80c-9748-4491-821a-9b0ce485d942.png from RGBA to RGB...
# Converting cac16836-a902-4dea-9f60-f43fd79e5ecd.png from RGBA to RGB...
# Converting 8201a130-8558-4aed-82a9-322ffced4c5e.png from RGBA to RGB...
# Converting 025295de-fb08-42f0-a33d-477ec41e12e4.png from RGBA to RGB...
# Converting fd9fe7d3-5f18-4ed3-8ef9-17ecc806edc5.png from RGBA to RGB...
# Converting f84e5991-9824-4692-8c23-9117ea88030e.png from RGBA to RGB...
# Converting 7df4ee6c-44fa-4e4b-8099-85e86fa29057.png from RGBA to RGB...
# Converting 1623b7b5-f52b-4c2d-b4a4-d054ab656f68.png from RGBA to RGB...
# Converting 76a8eed9-7023-4460-b474-b28bbe8f948c.png from RGBA to RGB...
# Converting f6443996-64fc-4028-9a69-985235217520.png from RGBA to RGB...
# Converting 9a0dba0d-25d4-4958-81f2-b12f7415bf09.png from RGBA to RGB...
# Converting 7eb785b1-c967-4c1c-8362-c0864ca28979.png from RGBA to RGB...
# Converting d68fc663-7c0f-449f-8a4d-a6075942be45.png from RGBA to RGB...
# Converting 109c5174-9974-474d-995d-96d65bca549f.png from RGBA to RGB...
# Converting 64689061-2876-444a-ab24-4c42bb3c362b.png from RGBA to RGB...
# Converting 4df8ea9f-f5da-4a77-8bfa-d85f96f88845.png from RGBA to RGB...
# Converting 2629942e-0f57-4321-b16c-54ac687f761c.png from RGBA to RGB...
# Converting d7739b95-7398-498d-ac76-d78cba758760.png from RGBA to RGB...
# Converting 2b3dc4db-d8b9-4449-bc05-8c7ff8326396.png from RGBA to RGB...
# Converting 25ad169c-9f10-45fd-8c60-bef192e7fbf0.png from RGBA to RGB...
# Converting c1c4e61a-0050-4f19-ac1a-87903f2cdf3a.png from RGBA to RGB...
# Converting b7a6fcaa-0e13-472f-b733-a2ff0fa5fa77.png from RGBA to RGB...
# Converting c2b3d82d-1931-4ea6-8cb8-8253ae19ba3d.png from RGBA to RGB...
# Converting 4f02c5c2-f50b-4cfb-869f-83255734b473.png from RGBA to RGB...
# Converting f8ad3c64-fae6-4e9e-b28f-4ba8041f30b8.png from RGBA to RGB...
# Converting f8fa56b8-d818-4787-a60f-b381d864897b.png from RGBA to RGB...
# Converting 53fd3c7b-89a4-40c4-8bd4-57463dd30ba8.png from RGBA to RGB...
# Converting b7af0e1f-3b17-4191-b37b-c47e4d92cdf4.png from RGBA to RGB...
# Converting 2bbc7c1a-315d-4b71-9b5f-4dcfdab13f90.png from RGBA to RGB...
# Converting b6e4e25d-a7af-45d2-a0c9-eeb96edd871a.png from RGBA to RGB...
# Converting 1da5720f-93e0-4e67-a89d-c0f6384780ab.png from RGBA to RGB...
# Converting 33714d3b-5bb8-440d-a55d-836b90346504.png from RGBA to RGB...
# Converting 060c4d9a-e5bb-48bf-b177-0ab4aa8c97cd.png from RGBA to RGB...
# Converting 922e9ca7-5caf-4575-ab01-3ad5903f0733.png from RGBA to RGB...
# Converting c84b6444-325a-423a-849f-c3cc6c771815.png from RGBA to RGB...
# Converting 8e02ccc9-bdce-4241-8157-1539c2623cff.png from RGBA to RGB...
# Converting 4bb08ec7-15cf-404c-b747-a53e2ba487ee.png from RGBA to RGB...
# Converting 9cdd47a0-505a-4675-a273-26a975b77647.png from RGBA to RGB...
# Converting 508a39ca-7ae7-4787-b058-ec7892eef6df.png from RGBA to RGB...
# Converting 14001bfc-d589-40bc-b96e-347999fa8630.png from RGBA to RGB...
# Converting 06d0352f-dec1-4458-8c39-add5577adc9c.png from RGBA to RGB...
# Converting 9ecfbede-b300-4265-9007-6891793a7f62.png from RGBA to RGB...
# Converting 73580c91-e187-435f-913e-c5b6e85aa853.png from RGBA to RGB...
# Converting 706b64fc-7f0e-4c6c-9d50-280226d91ee0.png from RGBA to RGB...
# Converting f580b0a3-de3e-4dc6-bc27-d9b6df16d34d.png from RGBA to RGB...
# Converting f47bfa1c-5515-4e9c-8990-b0fa659e930b.png from RGBA to RGB...
# Converting 704dfa28-c77f-414e-b9c5-890c98945129.png from RGBA to RGB...
# Converting bd42e98f-dc8f-4dd5-951b-67ed4d8d0a16.png from RGBA to RGB...
# Converting 39989c50-e044-40a8-9e4d-7d1bdfc67306.png from RGBA to RGB...
# Converting ab0cf250-9a6b-4790-9e91-612527cef58f.png from RGBA to RGB...
# Converting 1f8ed3ec-e8a9-4170-b022-873557f1a83e.png from RGBA to RGB...
# Converting 745489a4-51f9-45ed-8f95-85c753410f45.png from RGBA to RGB...
# Converting 6fc812a7-9bcd-43e1-80f8-088e03a1b4b6.png from RGBA to RGB...
# Converting 0f5b46e6-af4e-4156-899d-2fa2452465db.png from RGBA to RGB...
# Converting 83857376-42cf-44c9-8651-c27cdc341221.png from RGBA to RGB...
# Converting 68bc8147-4f6b-431c-99d1-bb39428b3ccf.png from RGBA to RGB...
# Converting c82a6fbb-a7bf-4982-b2de-0be3b31e31d8.png from RGBA to RGB...
# Converting 3178641f-0ebc-4459-b05a-60e3b5c99382.png from RGBA to RGB...
# Converting 308944a5-5437-47ed-9b31-25c53d2fd5f0.png from RGBA to RGB...
# Converting 8989a9f7-53f3-4eac-ad66-ff8e1e1de9ee.png from RGBA to RGB...
# Converting f29196a1-876b-4bd2-afdf-152ed2c079c6.png from RGBA to RGB...
# Converting 4b6eb1a2-5569-45f6-9a65-5f39876755e7.png from RGBA to RGB...
# Converting 2441c31f-d226-469b-9c8f-864c3cb42c24.png from RGBA to RGB...
# Converting 9541c567-e47c-432d-afa2-cf83ac016822.png from RGBA to RGB...
# Converting 24e56cf5-878e-4cbe-b0de-976e1145a50c.png from RGBA to RGB...
# Converting 04c60c83-48a6-48f7-a0ea-fe9dafa3964c.png from RGBA to RGB...
# Converting 48fa42fa-1d15-4237-9a8d-031f785883fd.png from RGBA to RGB...
# Converting 04d788c6-7cae-4857-8b6d-96740cbe51e6.png from RGBA to RGB...
# Converting 2d399218-3cfe-406a-b2c2-c754b68e2e06.png from RGBA to RGB...
# Converting 68b49eab-b9a2-4d8e-847d-54814e0c6f54.png from RGBA to RGB...
# Converting 85767927-9cbf-42b2-9afb-e95dc3438994.png from RGBA to RGB...
# Converting a7bd95d6-f6e8-4557-8c40-b59bd52b692f.png from RGBA to RGB...
# Converting bdd512d0-6798-425d-9901-f3c17c58e499.png from RGBA to RGB...
# Converting 210857ed-7152-4bf4-a1ce-4035d2d44631.png from RGBA to RGB...
# Converting 33d6323a-a9fa-4c4a-9ba4-8adfeb038409.png from RGBA to RGB...
# Converting 54c932d1-82aa-46e4-9905-1b3f4ebf55f7.png from RGBA to RGB...
# Converting e306c26d-431d-40f8-bc9c-4a6b4521d825.png from RGBA to RGB...
# Converting 4357e9d0-5e22-4488-bd17-754df4157df0.png from RGBA to RGB...
# Converting 623ffd2e-69a4-454f-b3f8-0c4e92560c1a.png from RGBA to RGB...
# Converting be8b0ca2-4526-4a07-a39c-91abec3b9f1e.png from RGBA to RGB...
# Converting fa8f5e90-8ef5-42c9-b41d-d500e5f5834d.png from RGBA to RGB...
# Converting d6023d3b-8aec-4b77-ac69-f9b39a2b5728.png from RGBA to RGB...
# Converting 720c3b92-d981-4136-afb4-e71972279560.png from RGBA to RGB...
# Converting a8109d90-b55a-48e7-b38b-a8721b6eff0b.png from RGBA to RGB...
# Converting 1c3f3592-08ef-4ebb-b1f0-727fdc8322d5.png from RGBA to RGB...
# Converting 1a08a259-58d3-419a-9909-464dc06c245a.png from RGBA to RGB...
# Converting 95ad3b6a-e67c-4146-823c-b51c4d9c1cbb.png from RGBA to RGB...
# Converting 68ffaf4d-b698-4360-af8f-8dde47eac2d0.png from RGBA to RGB...
# Converting 027f76ea-4151-469d-9059-2552fd5bc653.png from RGBA to RGB...
# Converting 4d1bcea2-1c8f-48b2-b62b-eb07040b2132.png from RGBA to RGB...
# Converting f7e8a6dc-8864-4999-b3a2-2ea13ae5a4f4.png from RGBA to RGB...
# Converting ea497549-3d8f-42eb-bca0-0d91dfa6a978.png from RGBA to RGB...
# Converting c4da0256-498c-4d23-8f2d-38a14ae1f7de.png from RGBA to RGB...
# Converting 739e6d6e-e7f3-492c-a2f3-c25857f63cd6.png from RGBA to RGB...
# Converting c12dc45d-64d2-40a8-ad11-f185f0c74033.png from RGBA to RGB...
# Converting 45522661-d60a-4818-ac4e-e800b5d0b82c.png from RGBA to RGB...
# Converting ec1ff8ac-af42-483a-b755-4f9ed06aebae.png from RGBA to RGB...
# Converting c148767f-850a-4eb4-a98d-e96d085563dc.png from RGBA to RGB...
# Converting fab7bee1-af8d-4832-920a-290caab9b28e.png from RGBA to RGB...
# Converting 5e4c55d4-3f06-4a8a-ad01-2a2da67ffa7b.png from RGBA to RGB...
# Converting de0d7294-0f2e-494e-8347-0ec912f96e99.png from RGBA to RGB...
# Converting f0ee737f-896b-4b12-a9a6-ac3e2d88c3bd.png from RGBA to RGB...
# Converting 223678a1-161d-4433-947e-78c3e91643e4.png from RGBA to RGB...
# Converting aec4209b-281b-4de4-9a7e-f8ec58d273f4.png from RGBA to RGB...
# Converting 296e4d8f-ad00-4690-b044-4170a05fd4f7.png from RGBA to RGB...
# Converting e0c855ca-c037-4081-a3b2-83db563d5071.png from RGBA to RGB...
# Converting 263e8fec-5d97-4224-a84f-715fe04b717f.png from RGBA to RGB...
# Converting ed6de180-d74d-4ea9-927d-82a7b873f831.png from RGBA to RGB...
# Converting 610cb010-9cde-420a-8463-dfa2cb3ebd33.png from RGBA to RGB...
# Converting 09adffe8-7431-427a-94f9-83c453ef5ff4.png from RGBA to RGB...
# Converting 22d9c31b-6429-4ee1-b287-f0f3e48fabbe.png from RGBA to RGB...
# Converting 08c5a2fa-c3b1-4ea8-8fb5-f52ec8ff3e03.png from RGBA to RGB...
# Converting df1649c6-ec7b-493a-b93d-205d2972a1cd.png from RGBA to RGB...
# Converting b2338151-934f-48c8-a279-e8ec42898bbe.png from RGBA to RGB...
# Converting 1f7fcd49-93f6-4f3c-b77f-227bba25c297.png from RGBA to RGB...
# Converting 03dff51f-a328-40ea-9f25-0a1582c9e227.png from RGBA to RGB...
# Converting ac7f7903-0aa1-4f15-96b4-f23e2776d062.png from RGBA to RGB...
# Converting 32004194-18d5-455c-a6a8-b89a2a3237f3.png from RGBA to RGB...
# Converting 898fa236-3b97-46b9-834b-184f8a82e7a5.png from RGBA to RGB...
# Converting ed33c31a-203e-4e34-b68a-79a9ffb660e4.png from RGBA to RGB...
# Converting 6c1f8e1e-e14b-4b94-b6ed-1b73a66c0a6d.png from RGBA to RGB...
# Converting 68b1efd5-f0cb-48d1-9953-7e4b863918e6.png from RGBA to RGB...
# Converting 5d64237f-0926-49e0-be9e-4e9b5e2ddeaa.png from RGBA to RGB...
# Converting ce88255b-7658-47bc-9b78-22abd7fe34bd.png from RGBA to RGB...
# Converting 97ca9a51-ee2b-40f8-b9f0-cd3909f2982d.png from RGBA to RGB...
# Converting eccf65fa-cbb0-486b-b2be-1f6627d9affd.png from RGBA to RGB...
# Converting 88005773-e015-4840-991a-e74005884237.png from RGBA to RGB...
# Converting 217d02a6-a7ff-476d-b22f-fcbe51a7a6e1.png from RGBA to RGB...
# Converting acbc498a-2343-43bd-b714-c63cde899ea2.png from RGBA to RGB...
# Converting 1dbe4bd5-7bc5-4aa0-9202-2df4723543d3.png from RGBA to RGB...
# Converting 9a057b0a-2977-4f09-ae43-e89afbe1e6e7.png from RGBA to RGB...
# Converting ddee5aef-904e-474f-892e-65b83e9ac3cb.png from RGBA to RGB...
# Converting 91a1b2b7-69a8-46ad-a1c9-9d7926ff7597.png from RGBA to RGB...
# Converting 4b725371-d76d-4332-bfa2-a2fd8192d5d2.png from RGBA to RGB...
# Converting 83687dcd-04e6-4ad0-a8ee-2b7885778173.png from RGBA to RGB...
# Converting 5f41a915-bbd4-47c9-b734-1b7e746e1e27.png from RGBA to RGB...
# Converting 6d2af1d5-3c02-4469-9914-0d49bd7693cf.png from RGBA to RGB...
# Converting df18c9a4-40e8-4c5b-be07-f77282e4f1ff.png from RGBA to RGB...
# Converting 4562fba9-76dc-48b8-9b5b-c14c80d6bab3.png from RGBA to RGB...
# Converting 76be170a-473d-4a8f-bf01-059b79a7ca19.png from RGBA to RGB...
# Converting cd81053a-1478-4adb-90df-09cc7856d29e.png from RGBA to RGB...
# Converting 856e28d3-a027-4ab5-9305-776e9632ed85.png from RGBA to RGB...
# Converting 7b66294c-7224-4721-8385-f58663e4e2a8.png from RGBA to RGB...
# Converting dbaad9de-71c4-4eac-b85e-186bdcdb98e3.png from RGBA to RGB...
# Converting 86e17e56-57a7-4f35-ade8-6358830c8e66.png from RGBA to RGB...
# Converting 65295082-d83d-46e7-9d52-2bd6e1672035.png from RGBA to RGB...
# Converting d63e37f9-2ad3-4af6-b2d4-53419af79d53.png from RGBA to RGB...
# Converting 6811f0c7-48fb-4380-bab2-62dff8cac9ec.png from RGBA to RGB...
# Converting 48b0fd23-1619-46e4-bda5-93bef30daffa.png from RGBA to RGB...
# Converting bbde9773-a9cb-47ec-a95e-f761532d4473.png from RGBA to RGB...
# Converting b5cc1142-1f42-430a-86bb-5b02bf159285.png from RGBA to RGB...
# Converting c92be6a2-c868-487e-a836-234a431740c4.png from RGBA to RGB...
# Converting 70a33d6b-77be-42ea-89e5-ef8dac4a5f9d.png from RGBA to RGB...
# Converting 548d304e-6b95-4602-b50c-1d52709e0a1f.png from RGBA to RGB...
# Converting d80e650f-82ab-4cc4-8c8f-9952b6e2de6b.png from RGBA to RGB...
# Converting e551f09f-decd-42d8-b408-c1132f778301.png from RGBA to RGB...
# Converting 0ec9d033-b0f9-4502-9099-3961a56f160f.png from RGBA to RGB...
# Converting 7e25c7ea-a9bc-43b6-a4e9-ca99155a563d.png from RGBA to RGB...
# Converting 06e98cdb-0185-4aa6-8820-a5649df76ffe.png from RGBA to RGB...
# Converting 215badd2-f84a-475f-a5eb-0e5701f60255.png from RGBA to RGB...
# Converting 45e90223-d8a3-4cef-8789-9a9b98ce446d.png from RGBA to RGB...
# Converting 37e7b3a4-0f2f-45e8-b61d-c9553227c24b.png from RGBA to RGB...
# Converting a4934eca-83a9-4ca2-ae46-c8f99aaa6661.png from RGBA to RGB...
# Converting 7d32020e-1318-450f-a09c-baf44e00d2db.png from RGBA to RGB...
# Converting b7476f0c-eedc-4c6d-8711-c4461a453ebf.png from RGBA to RGB...
# Converting 80e21814-6f14-49a0-aaf0-099f242b0118.png from RGBA to RGB...
# Converting dfb7c975-40a4-4805-9708-512398df4efb.png from RGBA to RGB...
# Converting bdbd5d30-28ba-46b2-b068-0c8c2f283931.png from RGBA to RGB...
# Converting 3ebe6c01-5198-4aec-9c27-d88023976114.png from RGBA to RGB...
# Converting 17fbce59-2974-41ff-8c6d-22be597e7dd3.png from RGBA to RGB...
# Converting d7cdcbb9-9e02-4430-aec0-77debe103fc3.png from RGBA to RGB...
# Converting c3cbcb82-0a62-4885-b378-5df2b7a3c090.png from RGBA to RGB...
# Converting 9ee4e09a-eeff-41fb-82b1-cf0907431c7e.png from RGBA to RGB...
# Converting bacbb370-457c-4737-aa35-b6eb04ce0b26.png from RGBA to RGB...
# Converting 911ed885-d1fb-498b-a472-9c95bb5409bb.png from RGBA to RGB...
# Converting 012dddff-2fe3-4a34-9884-3c0423d90076.png from RGBA to RGB...
# Converting 4f33eeb6-0e39-48f2-83e0-aef8a6fbcef0.png from RGBA to RGB...
# Converting 6dd4e36e-2d41-4e41-a540-e4a93c025c5f.png from RGBA to RGB...
# Converting d6a6d65a-f1c4-4aaa-afaf-14682d8d8785.png from RGBA to RGB...
# Converting 9b8f332c-1789-4db0-981e-a76bc114948d.png from RGBA to RGB...
# Converting cbd884ce-5f2f-4567-9298-ea4f95fbc5cb.png from RGBA to RGB...
# Converting 50e0278a-84ae-4993-9a59-7a97c2822604.png from RGBA to RGB...
# Converting da1f6250-7852-4dd2-953c-e699b1c3d862.png from RGBA to RGB...
# Converting 74c20b68-ae9e-4c4e-a4e8-8786e276746f.png from RGBA to RGB...
# Converting d8c765ec-4cb6-49cb-9e3d-bcae7760e298.png from RGBA to RGB...
# Converting 9eb00cf0-850d-49ea-b472-ad6bde9fa63d.png from RGBA to RGB...
# Converting be4fb1bb-6e02-46a4-9f93-3cc48d7e5be9.png from RGBA to RGB...
# Converting fa1ff229-d74c-4d27-a2a9-2757a149175e.png from RGBA to RGB...
# Converting 64c6b204-c25c-4ef0-a2b8-45aed165ee49.png from RGBA to RGB...
# Converting 18d895d0-04d0-49e7-b5ce-14629caf7c8e.png from RGBA to RGB...
# Converting 71d12ff7-01e3-49d0-bea1-86037f2252a7.png from RGBA to RGB...
# Converting b36fca5d-16be-4787-989a-237ccbec4e1e.png from RGBA to RGB...
# Converting 7159d566-be90-4fd1-ab73-750a70042e2c.png from RGBA to RGB...
# Converting f8397efa-62de-493e-ad87-50508a144ff3.png from RGBA to RGB...
# Converting 04517b98-5566-4f1d-ba80-39c8cff2de7c.png from RGBA to RGB...
# Converting ac035d91-2346-47a5-a8a1-ca2f738d0471.png from RGBA to RGB...
# Converting 8762dc82-c3bf-4b22-8bfd-fcfbb57560cf.png from RGBA to RGB...
# Converting ede9f93a-9b0f-4761-b481-e0dcf8fdc70b.png from RGBA to RGB...
# Converting 0cf9e2ac-632a-4621-8006-ca013f40d1de.png from RGBA to RGB...
# Converting 3fe59096-3102-4d3f-9577-b738245d87e5.png from RGBA to RGB...
# Converting 45dab520-940c-48f0-9aac-9fe572390af1.png from RGBA to RGB...
# Converting 748b6be0-4753-4ca3-8a6e-753a676f7073.png from RGBA to RGB...
# Converting 57e6f802-d52d-4617-a266-6f9c1cef81b5.png from RGBA to RGB...
# Converting 06dc3ff7-994f-4500-87e2-5045b4965c26.png from RGBA to RGB...
# Converting 5cb5fb73-d75b-4d0a-8322-850b8ab9fa85.png from RGBA to RGB...
# Converting 3ea8562a-cef5-453e-92aa-62a4e3700789.png from RGBA to RGB...
# Converting bfacd12d-5cba-457a-b18a-4b749ffa941d.png from RGBA to RGB...
# Converting e6cbe8ad-d76a-4e4b-97ae-79dd4b76386f.png from RGBA to RGB...
# Converting 9039d477-3927-4106-9d3d-fd5ba09e783e.png from RGBA to RGB...
# Converting 994e39df-3f29-4bcd-a7f7-897ce7a14bee.png from RGBA to RGB...
# Converting c09185db-2fef-4bf4-82d2-2ab0df36583f.png from RGBA to RGB...
# Converting 37e9a110-bf27-4e39-8da6-847a9013fbe9.png from RGBA to RGB...
# Converting e7822847-8a5e-4927-b86d-d85ae1640ea5.png from RGBA to RGB...
# Converting 3685a598-62ca-4eea-970c-82bd85b2a6ab.png from RGBA to RGB...
# Converting 2ed1e9e3-299d-4fde-ae0e-1e27e71749ed.png from RGBA to RGB...
# Converting 0602614d-d595-41bd-997b-f3e4e837dec3.png from RGBA to RGB...
# Converting 8934270c-3972-420b-a15f-5ed9a58a01fb.png from RGBA to RGB...
# Converting c36f893f-80ca-4282-9936-201767451a21.png from RGBA to RGB...
# Converting ac6b464f-ef5c-41b7-952b-8b5deec7d969.png from RGBA to RGB...
# Converting 04864c1d-fee3-4b8c-a796-cdfc6d9fbcd8.png from RGBA to RGB...
# Converting 76a305f7-c107-4c02-8d48-57467ca70aaa.png from RGBA to RGB...
# Converting c001275b-b040-424b-b481-e8241641c925.png from RGBA to RGB...
# Converting 6922c99c-71ae-45f3-a394-97a245c9ef1e.png from RGBA to RGB...
# Converting e4e9e606-62f3-4676-af85-a6f38673b3e9.png from RGBA to RGB...
# Converting 2d630cea-5592-4377-81db-f1eb8880679d.png from RGBA to RGB...
# Converting 83717234-36aa-4f1b-bd9a-eeb46d6967c2.png from RGBA to RGB...
# Converting 1adb00fa-532e-4d08-aa15-5bd8052aeea2.png from RGBA to RGB...
# Converting f73ad6b6-4c7f-4dd0-bbe4-02bb8f659eed.png from RGBA to RGB...
# Converting e858ab6c-4e7a-4b47-a9ef-608d6987e6bf.png from RGBA to RGB...
# Converting 6dc450c4-05be-4cfe-8763-a834ac35516a.png from RGBA to RGB...
# Converting e67782ba-e430-48c9-983f-ebbed0322b6e.png from RGBA to RGB...
# Converting 3fe343f2-ad1e-4d5a-b5a0-e08dac99d4d2.png from RGBA to RGB...
# Converting 1d2b6ef0-4987-40dd-87ea-cbfc5249cdd5.png from RGBA to RGB...
# Converting df424fae-8fb2-445b-98bb-ea223da51269.png from RGBA to RGB...
# Converting dc925167-51ae-4756-853b-6325a663188b.png from RGBA to RGB...
# Converting c2b39f91-8c66-4ba6-8e88-76351dd7dae9.png from RGBA to RGB...
# Converting 411ff7f4-0086-4064-9b18-4d538674a30f.png from RGBA to RGB...
# Converting d673232f-4f08-4618-8476-f0b240386a88.png from RGBA to RGB...
# Converting 2c86f1f2-41c2-41bb-91c6-d2f008946776.png from RGBA to RGB...
# Converting 33a2b676-dcbc-4340-bb59-e09ce5663a07.png from RGBA to RGB...
# Converting ad996973-2b27-476e-b34a-7cee39e2809e.png from RGBA to RGB...
# Converting 7c8ac183-43b8-4e2e-8626-abdf24cb61ef.png from RGBA to RGB...
# Converting 20308542-b880-48c5-86a7-d4e0647fc774.png from RGBA to RGB...
# Converting d1a772b2-e00c-49ec-9632-3aab45b8af1f.png from RGBA to RGB...
# Converting 7c50221b-c049-4b44-9fa4-adf00afcfc8e.png from RGBA to RGB...
# Converting 972f030c-844d-4f09-b681-6cf20b48582f.png from RGBA to RGB...
# Converting 29ff334b-35d7-45cd-a211-c289a41a434f.png from RGBA to RGB...
# Converting 59057cc0-d7b5-423a-bb16-ae2799738a4b.png from RGBA to RGB...
# Converting 67f5c3d4-84b9-4e1f-b0b5-28b54dfc3543.png from RGBA to RGB...
# Converting 405c84e0-ecfa-4b7f-9c76-030ee5ca6701.png from RGBA to RGB...
# Converting 8052f93d-b516-463c-9025-f789a11f4cc4.png from RGBA to RGB...
# Converting 483e3e4f-f5bd-4c1e-9905-6861e0301e69.png from RGBA to RGB...
# Converting b69a0439-eec5-4569-a9b4-38d5ecf764d8.png from RGBA to RGB...
# Converting 47042a7b-d8e2-4ee0-a0c2-6c6ac367c577.png from RGBA to RGB...
# Converting e226ede1-ca1d-4193-99e9-c062e78354bb.png from RGBA to RGB...
# Converting 09328e2b-14db-46a7-918c-9407aca9d819.png from RGBA to RGB...
# Converting ca4a835a-fd06-4770-84cd-669823240867.png from RGBA to RGB...
# Converting 0b2d2fc1-7dae-454c-a86d-c6bcf7da4e1a.png from RGBA to RGB...
# Converting 255c7dcf-98e3-4131-b027-2f56eef94728.png from RGBA to RGB...
# Converting 48367824-da35-453d-b8f3-97b1f1d2dc4c.png from RGBA to RGB...
# Converting 870e1216-c095-4fc0-842d-e85bbe4c3baa.png from RGBA to RGB...
# Converting d6a70b52-1758-4c8a-ac32-77436493765c.png from RGBA to RGB...
# Converting 17dc698f-76cf-490b-b6ee-c68769022ba1.png from RGBA to RGB...
# Converting d87b897c-4f35-4887-b9f5-94188f4b1b62.png from RGBA to RGB...
# Converting f606bfde-323c-4416-be35-e21f533ba665.png from RGBA to RGB...
# Converting bc232467-ac57-4016-ad38-fbb78fb6ef74.png from RGBA to RGB...
# Converting 12c5f33b-4188-4767-a98b-606c312f1693.png from RGBA to RGB...
# Converting 50da8287-b0a1-4693-9f93-6f4fc145b459.png from RGBA to RGB...
# Converting a6124012-6934-4317-b296-97c72779e828.png from RGBA to RGB...
# Converting 26460fe0-77d0-4cc9-a2ac-cc780449be75.png from RGBA to RGB...
# Converting 03648902-89f9-44d5-ac8b-4e334d376522.png from RGBA to RGB...
# Converting 2a1eed72-136c-4825-8638-0b37b007d829.png from RGBA to RGB...
# Converting ad954c5e-5679-4dc8-a594-64133da5c388.png from RGBA to RGB...
# Converting 999473c4-c25d-4556-af98-c88f6e719447.png from RGBA to RGB...
# Converting 9f653375-dd9d-40a1-b3a7-9acfaa04df49.png from RGBA to RGB...
# Converting 33387432-02cd-4941-be78-1460e7f8b3b8.png from RGBA to RGB...
# Converting 4ae4b6c0-4e2a-421a-aac9-ecdd6a3cdb32.png from RGBA to RGB...
# Converting 0e608ec0-fa30-402f-af9f-fee9fbefe634.png from RGBA to RGB...
# Converting c21ec314-a2ca-4ad8-99b5-adb179774ee0.png from RGBA to RGB...
# Converting cd90e578-0c32-4cba-a7cd-0abde67e2610.png from RGBA to RGB...
# Converting 4d9c2f2d-4efb-4cd3-ab10-86233a5c0dfd.png from RGBA to RGB...
# Converting f0f7014b-d2a7-4059-856e-0047e2c112a3.png from RGBA to RGB...
# Converting 99e29734-703b-40a3-9f84-2ef1cefd713a.png from RGBA to RGB...
# Converting 365a9ecc-890c-49cf-b9d9-9857c273eaac.png from RGBA to RGB...
# Converting 58299381-9c45-433f-8173-60406fe77f03.png from RGBA to RGB...
# Converting 6fb0e627-d22f-47a1-a84e-46d67cadd582.png from RGBA to RGB...
# Converting d327b5e2-adb8-47e0-89cb-5babdec75898.png from RGBA to RGB...
# Converting 35cbc668-bbd8-4490-a956-aab8194a3e0e.png from RGBA to RGB...
# Converting 5ea85497-1fc3-4106-b1bb-10913f625049.png from RGBA to RGB...
# Converting 20d43e3e-c56b-4c5c-8c7a-41088ac38195.png from RGBA to RGB...
# Converting 40504b8c-e34e-4196-9bf3-0ae21e919ec8.png from RGBA to RGB...
# Converting eaa63382-def7-4100-850d-10586092cb3b.png from RGBA to RGB...
# Converting c92a9071-4ba0-4a89-9288-74eb9b181580.png from RGBA to RGB...
# Converting 5c653efe-405f-4b4d-9cdd-4047b038d6c3.png from RGBA to RGB...
# Converting a1123394-b2d7-488f-b953-790af5a22045.png from RGBA to RGB...
# Converting 209910f4-fdb0-4f6f-8635-4826e6cdb343.png from RGBA to RGB...
# Converting 00f16550-0e31-4ccd-88c2-df43ba069e33.png from RGBA to RGB...
# Converting b06a45ae-e9a5-4e5a-9cf4-3733ba1b4149.png from RGBA to RGB...
# Converting e35df0e3-c9e4-4748-b31e-b8026213e8b0.png from RGBA to RGB...
# Converting 4f9fe7d7-3346-4bdf-9cf8-f0ad78b38c3c.png from RGBA to RGB...
# Converting 60c9cb40-8544-4187-b565-9cc97982ee69.png from RGBA to RGB...
# Converting 97f5d16a-ec50-4af5-9fc9-c13084d77b07.png from RGBA to RGB...
# Converting 5aa2eb24-c6e1-45df-9018-6235b201b30b.png from RGBA to RGB...
# Converting d2bc072a-900f-4074-8d8a-da1837e08c2b.png from RGBA to RGB...
# Converting 30ece86b-629b-4ce0-879f-357f4610f710.png from RGBA to RGB...
# Converting d0740cd2-2294-45d6-8b93-de6b9e51c5ab.png from RGBA to RGB...
# Converting f88006d6-c46c-4ab1-94e7-62c9864727fc.png from RGBA to RGB...
# Converting b343c944-e61f-46eb-a8cf-cf4ac1bb1ca5.png from RGBA to RGB...
# Converting 91b2784b-8083-4a38-8577-938d559f3d6c.png from RGBA to RGB...
# Converting 376fb493-5044-4401-91fa-1868c7199225.png from RGBA to RGB...
# Converting 10a3d907-c8b5-4a6a-ab25-2725e6f81ed6.png from RGBA to RGB...
# Converting 535df5d3-df4a-4316-8496-b66b15a13428.png from RGBA to RGB...
# Converting 9bb47e3a-c750-4b7d-b38c-9ddf708b35ed.png from RGBA to RGB...
# Converting 5579e49b-0d62-4dd7-8662-84b4c10192c3.png from RGBA to RGB...
# Converting 2b9d504c-cfbf-4c8d-85ef-d1b838eb3be8.png from RGBA to RGB...
# Converting 4f479aa1-e382-41b9-a2ac-839004cb1cb3.png from RGBA to RGB...
# Converting 96835b74-9d8a-44c9-8b9b-a7197e9e821f.png from RGBA to RGB...
# Converting ad7b6eba-adf3-491d-a218-576ffa9e301c.png from RGBA to RGB...
# Converting 161dd62d-1504-42f2-abbd-1ad786055425.png from RGBA to RGB...
# Converting d1639be9-091a-49e8-be82-216c1a1b2cdf.png from RGBA to RGB...
# Converting f55aad62-5028-4008-9721-5b4a002c1999.png from RGBA to RGB...
# Converting e62169a7-581d-40e8-b0c4-e1b329e4176c.png from RGBA to RGB...
# Converting 1e45ef7b-a1e0-44b7-a809-eab4245e90c8.png from RGBA to RGB...
# Converting 7a12d550-66b9-400f-bca6-5b3651b3a8f3.png from RGBA to RGB...
# Converting 4e570a56-dda2-4ef9-ae5d-5f40e42e210a.png from RGBA to RGB...
# Converting eda3a806-abc9-4c53-8a7e-f4583097148a.png from RGBA to RGB...
# Converting 53943ff4-40c4-4e7c-bf4b-3da084659938.png from RGBA to RGB...
# Converting 8fad8764-823c-417a-b6e6-2cb1228fa4ba.png from RGBA to RGB...

# %% [markdown]
# # Install libraries

# %% [markdown]
# The requirements available on the github did not work in my computer, so I manually installed the necessary libraries

# %%
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from PyWavelets) (1.26.4)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 55.2 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (0.4)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
# !pip install click
# Out:
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (8.1.7)

# %%
# !git clone https://github.com/felipeinagaki/UnderWaterPreprocessing.git
# Out:
# Cloning into 'UnderWaterPreprocessing'...
# remote: Enumerating objects: 97, done.
# remote: Total 97 (delta 0), reused 0 (delta 0), pack-reused 97 (from 1)
# Receiving objects: 100% (97/97), 55.87 MiB | 15.60 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
# %cd UnderWaterPreprocessing
# Out:
# /content/UnderWaterPreprocessing

# %%
# !ls
# Out:
# checkpoints	  download_data.ipynb  models		   requirements.txt  train_multi.py
# Comparison.ipynb  eval.json	       MS_SSIM_L1_loss.py  results
# dataset		  Images	       output.png	   test_multi.py
# dataset_nyu.py	  LICENSE	       README.md	   train.json

# %%
os.path.exists('checkpoints/model.pth')
# Out:
# True

# %% [markdown]
# In the code below, change --test_size with the number of images that will be processed, otherwise it will only process 890

# %%
# !python test_multi.py train --test_dataset train --data_path /content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/original/ --model_load_path checkpoints/model.pth --test_size 5950
# Out:
# /content/UnderWaterPreprocessing/test_multi.py:92: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_load_path))
# 5950it [3:02:08,  1.84s/it]

# %%
import os

def count_images(directory):
  """Counts the number of image files in a directory.

  Args:
    directory: The path to the directory.

  Returns:
    The number of image files found.
  """
  image_extensions = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff')  # Add more if needed
  image_count = 0
  for filename in os.listdir(directory):
    if filename.lower().endswith(image_extensions):
      image_count += 1
  return image_count

# Example usage:
directory_path = '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/'  # Replace with your directory path
num_images = count_images(directory_path)
print(f"Number of images in '{directory_path}': {num_images}")
# Out:
# Number of images in '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/': 5950

# %% [markdown]
# ## Change names
# If desired, change the name of the outputs

# %%
import os
from PIL import Image

input_folder = "results/eval/None/"

output_folder = "results/png/eval"
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith(".png_out.jpg"):
        input_path = os.path.join(input_folder, filename)

        new_name = filename.replace(".png_out.jpg", ".png")

        output_path = os.path.join(output_folder, new_name)

        try:
            with Image.open(input_path) as img:
                img.save(output_path, "PNG")
        except Exception as e:
            print(f"Error when processing {filename}: {e}")

# %%
# import shutil
# import os

# # Define source and destination directories
# source_dir = '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/train/None'
# destination_dir = '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train'

# # Iterate through files and directories in the source directory
# for item in os.listdir(source_dir):
#     source_path = os.path.join(source_dir, item)
#     destination_path = os.path.join(destination_dir, item)

#     # Move the item to the destination directory
#     shutil.move(source_path, destination_path)

# print(f"Files moved from '{source_dir}' to '{destination_dir}'")
# Out:
# Files moved from '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/train/None' to '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train'

# %%
# Example usage:
directory_path = '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/'  # Replace with your directory path
num_images = count_images(directory_path)
print(f"Number of images in '{directory_path}': {num_images}")
# Out:
# Number of images in '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/': 4874

# %% [markdown]
# Show specific images to compare

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

original_folder = "/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/original/"
processed_folder = "/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/"

image_files = [
    "0a1cca8f-9e74-488d-a92a-eadd0e9d529a.png",
    "0a1ddbaf-3db9-41ef-84a8-d1bba2c8329d.png",
    "0a4e1af0-c332-4211-bf10-246682ebd32d.png",
    "0a5ee259-d0e6-4885-adf9-7a62a57043fb.png",
    "0a6c68cb-28ef-4126-9615-c3bf76f7a44b.png"
]

original_images = [Image.open(os.path.join(original_folder, img)) for img in image_files]
processed_images = [Image.open(os.path.join(processed_folder, img)) for img in image_files]

fig, axes = plt.subplots(len(image_files), 2, figsize=(10, 3 * len(image_files)))

axes[0, 0].set_title("Original", fontsize=14)
axes[0, 1].set_title("Result", fontsize=14)

for i, (orig_img, proc_img) in enumerate(zip(original_images, processed_images)):
    axes[i, 0].imshow(orig_img)
    axes[i, 0].axis("off")

    axes[i, 1].imshow(proc_img)
    axes[i, 1].axis("off")

fig.suptitle("Preprocessing Results", fontsize=16)

plt.tight_layout()  # Reservar espaço para o título
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-b549e688ffd3> in <cell line: 17>()
#      15
#      16 original_images = [Image.open(os.path.join(original_folder, img)) for img in image_files]
# ---> 17 processed_images = [Image.open(os.path.join(processed_folder, img+'_out.jpg')) for img in image_files]
#      18
#      19 fig, axes = plt.subplots(len(image_files), 2, figsize=(10, 3 * len(image_files)))
#
# <ipython-input-33-b549e688ffd3> in <listcomp>(.0)
#      15
#      16 original_images = [Image.open(os.path.join(original_folder, img)) for img in image_files]
# ---> 17 processed_images = [Image.open(os.path.join(processed_folder, img+'_out.jpg')) for img in image_files]
#      18
#      19 fig, axes = plt.subplots(len(image_files), 2, figsize=(10, 3 * len(image_files)))
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3467
#    3468     if filename:
# -> 3469         fp = builtins.open(filename, "rb")
#    3470         exclusive_fp = True
#    3471     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/fathomnet-out-of-sample-detection/preprocessed/train/0a4e1af0-c332-4211-bf10-246682ebd32d.png_out.jpg'
